# %% [markdown]
# # Systematic Similarity

# %%
import numpy as np   #for numerical calculation
import pandas as pd  #for data analysis

import string 
import regex # regular expression
from nltk.corpus import stopwords # to remove stopwords using nltk library

# %%
df=pd.read_csv('t1.csv') # reading the data which we cleaned before

# %%
df.info() # data information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33573 entries, 0 to 33572
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   33573 non-null  int64
#  1   category     33573 non-null  object
#  2   description  33573 non-null  object
#  3   title        33573 non-null  object
#  4   brand        33573 non-null  object
#  5   date         33573 non-null  object
#  6   price        33573 non-null  float64
#  7   asin         33573 non-null  object
#  8   imageURL     33573 non-null  object
#  9   overall      33573 non-null  int64
#  10  verified     33573 non-null  bool
#  11  reviewTime   33573 non-null  object
#  12  reviewText   33573 non-null  object
#  13  reviewerID   33573 non-null  object
#  14  Sentimental  33573 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(11)
# memory usage: 3.6+ MB

# %%
df.isnull().sum() # finding null values
# Out:
# Unnamed: 0     0
# category       0
# description    0
# title          0
# brand          0
# date           0
# price          0
# asin           0
# imageURL       0
# overall        0
# verified       0
# reviewTime     0
# reviewText     0
# reviewerID     0
# Sentimental    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental
# 0  A2WJLOXXIB7NF3     Neutral
# 1  A1RKICUK0GG6VF    Positive
# 2  A1QA5E50M398VW    Positive
# 3  A3N0HBW8IP8CZQ    Positive
# 4  A1K1JW1C5CUSUZ    Positive

# %%
df1=df[:10000] # slicing data because my pc doesnt support large data

# %%
def text_process(text): # cleaning the data
    nopunc = [char for char in  text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
def list_to_string(s): # converting list to string
    str1 = " "
    return (str1.join(s))

# %%
# cleaning the dataset
df1['Product_name']=df1['title'].apply(text_process)
df1['category_for_rec']=df1['category'].apply(text_process)
df1['description_for_rec']=df1['description'].apply(text_process)
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\939280148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['title'].apply(text_process)
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\939280148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category'].apply(text_process)
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\939280148.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description'].apply(text_process)

# %%
# converting data from list to string
df1['Product_name']=df1['Product_name'].apply(list_to_string)
df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\1776642517.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['Product_name'].apply(list_to_string)
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\1776642517.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\1776642517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental     Product_name  \
# 0  A2WJLOXXIB7NF3     Neutral  Pocket Corduroy
# 1  A1RKICUK0GG6VF    Positive  Pocket Corduroy
# 2  A1QA5E50M398VW    Positive  Pocket Corduroy
# 3  A3N0HBW8IP8CZQ    Positive  Pocket Corduroy
# 4  A1K1JW1C5CUSUZ    Positive  Pocket Corduroy
#
#                                     category_for_rec  \
# 0  Office Products Office School Supplies Educati...
# 1  Office Products Office School Supplies Educati...
# 2  Office Products Office School Supplies Educati...
# 3  Office Products Office School Supplies Educati...
# 4  Office Products Office School Supplies Educati...
#
#                                  description_for_rec
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...
# 2  Corduroy bear goes launderette Lisa overhears ...
# 3  Corduroy bear goes launderette Lisa overhears ...
# 4  Corduroy bear goes launderette Lisa overhears ...

# %%
df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\15092516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental     Product_name  \
# 0  A2WJLOXXIB7NF3     Neutral  Pocket Corduroy
# 1  A1RKICUK0GG6VF    Positive  Pocket Corduroy
# 2  A1QA5E50M398VW    Positive  Pocket Corduroy
# 3  A3N0HBW8IP8CZQ    Positive  Pocket Corduroy
# 4  A1K1JW1C5CUSUZ    Positive  Pocket Corduroy
#
#                                     category_for_rec  \
# 0  Office Products Office School Supplies Educati...
# 1  Office Products Office School Supplies Educati...
# 2  Office Products Office School Supplies Educati...
# 3  Office Products Office School Supplies Educati...
# 4  Office Products Office School Supplies Educati...
#
#                                  description_for_rec  \
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...
# 2  Corduroy bear goes launderette Lisa overhears ...
# 3  Corduroy bear goes launderette Lisa overhears ...
# 4  Corduroy bear goes launderette Lisa overhears ...
#
#                                        combined_text
# 0  Pocket Corduroy Office Products Office School ...
# 1  Pocket Corduroy Office Products Office School ...
# 2  Pocket Corduroy Office Products Office School ...
# 3  Pocket Corduroy Office Products Office School ...
# 4  Pocket Corduroy Office Products Office School ...

# %%
df2=df1[['Product_name','category_for_rec','description_for_rec','combined_text']] # taking only required column for further anlaysis

# %%
df2.combined_text[0]
# Out:
# 'Pocket Corduroy Office Products Office School Supplies Education Crafts Early Childhood Education Materials Corduroy bear goes launderette Lisa overhears mother warn taking things pockets washing clothes Corduroy discovers pocket begins search find one'

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      -------------------------------------- 227.1/227.1 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (1.23.5)
# Collecting huggingface-hub>=0.15.1
#   Downloading huggingface_hub-0.23.3-py3-none-any.whl (401 kB)
#      -------------------------------------- 401.7/401.7 kB 2.3 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.34.0
#   Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: scipy in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: Pillow in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: scikit-learn in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from sentence-transformers) (1.12.1)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#      -------------------------------------- 176.9/176.9 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\shahid\anaconda3\new folder\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.1)
# Requirement already satisfied: filelock in c:\users\shahid\anaconda3\new folder\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: colorama in c:\users\shahid\anaconda3\new folder\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2022.7.9)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.3-cp310-none-win_amd64.whl (287 kB)
#      -------------------------------------- 287.4/287.4 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shahid\anaconda3\new folder\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2022.12.7)
# Installing collected packages: safetensors, fsspec, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
# Successfully installed fsspec-2024.6.0 huggingface-hub-0.23.3 safetensors-0.4.3 sentence-transformers-3.0.1 tokenizers-0.19.1 transformers-4.41.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer # sentence tranformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2') # one of model from hugging face
# Out:
# C:\Users\SHAHID\anaconda3\New folder\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# # Embedding

# %%
df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_16388\4155631282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector

# %%
df2.sample(20)
# Out:
#         Product_name                                   category_for_rec  \
# 69   Pocket Corduroy  Office Products Office School Supplies Educati...
# 73   Pocket Corduroy  Office Products Office School Supplies Educati...
# 51   Pocket Corduroy  Office Products Office School Supplies Educati...
# 39   Pocket Corduroy  Office Products Office School Supplies Educati...
# 49   Pocket Corduroy  Office Products Office School Supplies Educati...
# 100  Pocket Corduroy  Office Products Office School Supplies Educati...
# 23   Pocket Corduroy  Office Products Office School Supplies Educati...
# 72   Pocket Corduroy  Office Products Office School Supplies Educati...
# 4    Pocket Corduroy  Office Products Office School Supplies Educati...
# 102  Pocket Corduroy  Office Products Office School Supplies Educati...
# 40   Pocket Corduroy  Office Products Office School Supplies Educati...
# 88   Pocket Corduroy  Office Products Office School Supplies Educati...
# 5    Pocket Corduroy  Office Products Office School Supplies Educati...
#        -2.58957818e-02,  9.07460507e-03, -6.89200033e-03,  1.92672722e-02,
#         2.23028697e-02,  7.60993436e-02,  8.74939039e-02, -3.35211503e-08,
#        -4.27009575e-02, -1.66382045e-02,  2.58520395e-02, -4.32687886e-02,
#         8.03483352e-02, -7.34977350e-02,  6.43692678e-03,  3.76159847e-02,
#         4.79859952e-03,  6.32407218e-02, -3.12639140e-02, -8.48399401e-02,
#        -3.94082144e-02,  2.94069219e-02,  3.78450416e-02,  4.23614774e-03,
#         5.30049950e-02, -5.79071529e-02, -2.19648946e-02, -2.12353133e-02,
#         1.03725284e-01, -5.62358610e-02,  6.22268505e-02,  6.20449856e-02,
#        -1.75727054e-03, -4.46551479e-02, -8.80589932e-02,  2.74033546e-02,
#        -2.61768233e-02,  1.17937282e-01,  2.80205254e-02,  2.00691689e-02,
#        -5.55946641e-02, -6.73415363e-02, -3.11462721e-03, -5.18175401e-02,
#        -2.72441320e-02, -6.60263672e-02, -9.02367011e-03,  7.19254017e-02,
#         5.77992499e-02, -8.52915198e-02,  4.36734073e-02,  3.31798792e-02,
#        -1.34221539e-02, -4.54084873e-02,  9.81976092e-02, -1.10290430e-01,
#        -2.67035402e-02,  6.18134858e-03, -4.52387854e-02, -2.65022963e-02,
#         3.71246599e-02, -5.75370714e-02,  3.04794032e-02, -5.39513305e-03,
#        -6.10408634e-02, -1.30715612e-02,  1.60520766e-02,  4.45541181e-02,
#        -8.63959268e-02, -7.13794492e-03,  2.71458365e-02, -8.11120030e-03],
#       dtype=float32)

# %%
#df2.to_csv('data_with_embeddings.csv',index=False)

# %% [markdown]
# # Cosine Similarity

# %%
from sentence_transformers import util # cosine similarity

# %%
def get_similar_products(combined_input, df, top_n=2):
    combined_embedding = model.encode(combined_input)
    
    similarities = util.pytorch_cos_sim(combined_embedding, df2['combined_embedding'])
    
    print(similarities)
    
    similar_indices = similarities.argsort(descending= True,axis = 1)[0][:top_n]
    print(similar_indices)
    
    similar_items_df = df2.iloc[similar_indices][['Product_name','category_for_rec','description_for_rec']]
    #print(similar_items)
    return similar_items_df

# %%
product_info_to_search = "Colorful Chalkboard"

similar_items = get_similar_products(product_info_to_search,df2)
similar_items
# Out:
# tensor([[0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228,
#          0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228, 0.2228]])
# tensor([0, 1])
#       Product_name                                   category_for_rec  \
# 0  Pocket Corduroy  Office Products Office School Supplies Educati...
# 1  Pocket Corduroy  Office Products Office School Supplies Educati...
#
#                                  description_for_rec
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...

# %%
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
# Out:
# Colorful Chalkboard
#
# Similar Products:
# Product : Pocket Corduroy
# Product : Pocket Corduroy

# %%
product_info_to_search = input("Enter Keywords : ")

similar_items = get_similar_products(product_info_to_search,df2)
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
similar_items
# Out:
# Enter Keywords : book
# tensor([[0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436,
#          0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436, 0.2436]])
# tensor([0, 1])
# book
#
# Similar Products:
# Product : Pocket Corduroy
# Product : Pocket Corduroy
#       Product_name                                   category_for_rec  \
# 0  Pocket Corduroy  Office Products Office School Supplies Educati...
# 1  Pocket Corduroy  Office Products Office School Supplies Educati...
#
#                                  description_for_rec
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...
